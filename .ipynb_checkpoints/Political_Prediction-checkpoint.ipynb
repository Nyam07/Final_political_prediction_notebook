# %% [markdown]
# # Project to predict the popularity of Political leaders and detect hate speech and tribalism from Facebook and Twitter comments

# %% [markdown]
# ## Imports

# %%
from webdriver_manager.chrome import ChromeDriverManager

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.service import Service

from bs4 import BeautifulSoup

import pandas as pd

import time

# for tweets collection
import tweepy

# text cleaning
import preprocessor as p

# text preprocessing
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.corpus import wordnet

#lemmatization
from nltk.stem import WordNetLemmatizer

#sentiment analysis
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn
from nltk.tag import pos_tag

## visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# get the language of the text
import langdetect
#for ner recognition
import spacy

from langdetect.lang_detect_exception import LangDetectException

#Hatespeech imports
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

#to data preprocessing
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

#NLP tools
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

#train split and fit models
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
  
#model selection
from sklearn.metrics import confusion_matrix, accuracy_score

# %% [markdown]
# # GET FACEBOOK COMMENTS

# %%
# scroll down
def scroll():
    pop_out_btn = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.ID, "popup_xout")))
    pop_out_btn.click()

# %%
# funtion to click the view more button
def view_more_click(driver):
    try: 
        view_more_comments = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.LINK_TEXT, "View more comments…")))
        view_more_comments.click()
    
    except TimeoutException:
        view_more_comments = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.LINK_TEXT, "View previous comments…")))
        view_more_comments.click()
        
    except ElementClickInterceptedException:
        scroll()
    
    except (NoSuchElementException,ElementClickInterceptedException, StaleElementReferenceException) as es :
        print(es)
    html = driver.page_source
    return html

# function to click the button 50 times
def view_more_comm(driver):
    i = 0
    while i < 50:
        html = view_more_click(driver)
        time.sleep(3)
        i += 1
    return html

# %%
# function to get a list of all the comment elements
def get_comments():
    html = view_more_comm(driver)
    soup = BeautifulSoup(html, 'html.parser')
    comment_section = soup.find("div", {"class":"_59e9 _1-ut _2a_g _34oh" })
    comment_els = comment_section.find_all("div", {"class":"_2a_i"})
    
    master_list = []
    for c in comment_els:
        data_dict = {}
        data_dict["User"] = c.find("div", {"class":"_2b05"}).text
        data_dict["Data"] = c.find("div", {"data-sigil":"comment-body"}).text
        master_list.append(data_dict)
    return master_list

# %% [markdown]
# # GETTING TWITTER DATA

# %% [markdown]
# ## Twitter Authentication

# %%
# read the keys from the file 
def authorize_twitter():
    keys = []
    with open('../Keys.txt') as f:
        for line in f:
            keys.append(line.strip())

    API_KEY = keys[1]
    API_KEY_SECRET = keys [4]
    ACCESS_TOKEN = keys[10]
    ACCESS_TOKEN_SECRET = keys[13]
    
    # initialize the api
    auth = tweepy.OAuthHandler(API_KEY, API_KEY_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
    api = tweepy.API(auth)
    
    return (api)

# %% [markdown]
# ## Get the replies from the posts

# %%
def get_replies(url):
    name = url.split("/")[-3]
    tweet_id = url.split("/")[-1]

    #empty list for the replies
    replies = []
    
    api = authorize_twitter()
    # get replies from the tweet
    for tweet in tweepy.Cursor(api.search_tweets,q='to:'+name, result_type='recent', tweet_mode = "extended").items(1000):
        if hasattr(tweet, 'in_reply_to_status_id_str'):
            if (tweet.in_reply_to_status_id_str==tweet_id):
                replies.append(tweet)
    
    #master list to hold all the data needed
    master_list = []
    for reply in replies:
        data_dict = {}
        data_dict["User"] = reply.author.screen_name
        data_dict["Data"] = reply.full_text

        master_list.append(data_dict)
        
    return (master_list)

# %%
 def get_topic_tweets(topic, items_returned):
        api = authorize_twitter()
        tweets = tweepy.Cursor(
            api.search_tweets, q=topic, lang='en', tweet_mode="extended").items(items_returned)

        master_list = []
        for tweet in tweets:
            #remove the retweet tag from the text
            final_text = tweet.full_text.replace('RT', '')
            data_dict = {}
            data_dict["User"] = tweet.author.screen_name
            data_dict['Data'] = final_text
            master_list.append(data_dict)

        return master_list

# %% [markdown]
# # TEXT PREPROCESSING

# %% [markdown]
# ## Tokenization and POS tagging + removing stop words

# %%
#perform tokenization and pos tagging and remove stop words
pos_dict = {'J': wordnet.ADJ, 'v': wordnet.VERB, 'N': wordnet.NOUN, 'R': wordnet.ADV}
def token_stop_pos(text):
    tags = pos_tag(word_tokenize(text))
    newlist = []
    
    for word, tag in tags:
        if word.lower() not in set(stopwords.words('english')):
            newlist.append(tuple([word, pos_dict.get(tag[0])]))
            
    return newlist

# %% [markdown]
# ## Lemmatization

# %%
wordnet_lemmatizer = WordNetLemmatizer()
def lemmatize(pos_data):
    lemma_rew = " "
    for word, pos in pos_data:
        if not pos:
            lemma = word
            lemma_rew = lemma_rew + " " + lemma
        else:
            lemma = wordnet_lemmatizer.lemmatize(word, pos=pos)
            lemma_rew = lemma_rew + " " + lemma
    return lemma_rew

# %% [markdown]
# ## Language detection

# %%
def get_language(text):
    try:
        lang = langdetect.detect(text)
        
        return lang
    except LangDetectException:
        print(text, "is invalid")

# %% [markdown]
# ## SENTIMENT ANALYSIS USING VADER

# %%
def vaderSentimentAnalysis(text):
    analyzer = SentimentIntensityAnalyzer()
    vs= analyzer.polarity_scores(text)
    return vs['compound']

# function to analyse 
def vader_analysis(compound):
    if compound > 0:
        return 'Positive'
    elif compound < 0 :
        return 'Negative'
    else:
        return 'Neutral'

# %% [markdown]
# ## Get names and parties from the text

# %%
def get_parties(text):
    parties="None"
    for i in range(len(text)):
        tags = text[i][1]
        if tags == "POLITICAL_PARTY":
            party = text[i][0]
            if party not in parties:
                parties=party
        else:
            continue
        return parties

# %%
def get_names(text):
    names="None"
    for i in range(len(text)):
        tags = text[i][1]
        if tags == "POLITICIAN":
            name = text[i][0]
            names=name
            break
        else:
            return "None"
            continue
    return names

# %%
stemmer = nltk.SnowballStemmer("english")
stopword=set(stopwords.words('english'))
def clean_text(text):
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = [word for word in text.split(' ') if word not in stopword]
    text=" ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')]
    text=" ".join(text)
    return text

# %% [markdown]
# # MAIN FILE

# %%
choice = input("Please select the choice of your data. \n 1. for facebook. \n 2. For twitter. \n 3. For collecting tweets on a topic")
if choice == "1":
    # install webdriver
    options = webdriver.ChromeOptions()
    options.add_argument("headless")
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
    url = input("Paste the Facebook mobile url: ")
    driver.get(url)

    print("Getting comments please wait...\n")
    master_list = get_comments()
        
elif choice == "2":
    url = input("Paste the tweet url: ")
    print("----Getting replies please wait------")
    master_list = get_replies(url)

elif choice == "3":
    topic = input("Enter the topic you want to search for: ")
    results_returned = input("Enter the number of results returned: ")
    
    print("Getting tweets...")
    master_list = get_topic_tweets(topic, int(results_returned))
    
else:
    print("Invalid input")
    
print(str(len(master_list)) + " Comments found")
# Out:
# Please select the choice of your data.
#  1. for facebook.
#  2. For twitter.
#  3. For collecting tweets on a topic3
# Enter the topic you want to search for: Raila
# Enter the number of results returned: 200
# Getting tweets...
# 200 Comments found

# %% [markdown]
# ## Dataframe Creation

# %%
df = pd.DataFrame(master_list)
df["clean_tweets"] = df["Data"].apply(lambda x: p.clean(x))
df
# Out:
#                 User                                               Data  \
# 0     Wilson38573694   @Kenyans: Uhuru associating himself with Rail...
# 1         BernetOjay   @gabrieloguda: BREAKING: A group of Posh Luos...
# 2         _John_Best   @FrankMtetezi: In the 48 Laws of power ,Never...
# 3          Kips_Manu   @DavisKRuto: Raila Odinga's name does not fea...
# 4          mcmatata1   @kiraguisaac_22: H.E Uhuru kenyatta could not...
# ..               ...                                                ...
# 195    zalendomartin   @HezMureithi: KENYA DECIDES🗳 2022\nWhich Team...
# 196  Raphael14822774   @kuriasolomonK: If you will vote for Raila Od...
# 197        Kamangara   @HezMureithi: KENYA DECIDES🗳 2022\nWhich Team...
# 198      OsoroYobesi  Kenyans should be told that it's also unethica...
# 199           RasKE_   @pascalo_pascal: @RasKE_ How comes raila neve...
#
#                                           clean_tweets
# 0    : Uhuru associating himself with Raila and Mar...
# 1    : BREAKING: A group of Posh Luos, who told us ...
# 2    : In the Laws of power ,Never try to outshine ...
# 3    : Raila Odinga's name does not feature in the ...
# 4    : H.E Uhuru kenyatta could not afford time for...
# ..                                                 ...
# 195  : KENYA DECIDES Which Team are You going to VO...
# 196  : If you will vote for Raila Odinga because he...
# 197  : KENYA DECIDES Which Team are You going to VO...
# 198  Kenyans should be told that it's also unethica...
# 199  : How comes raila never won and the way he was...
#
# [200 rows x 3 columns]

# %% [markdown]
# ## Text Preprocessing

# %%
df['POS tagged'] = df['clean_tweets'].apply(lambda x: token_stop_pos(x))
df
# Out:
#                 User                                               Data  \
# 0     Wilson38573694   @Kenyans: Uhuru associating himself with Rail...
# 1         BernetOjay   @gabrieloguda: BREAKING: A group of Posh Luos...
# 2         _John_Best   @FrankMtetezi: In the 48 Laws of power ,Never...
# 3          Kips_Manu   @DavisKRuto: Raila Odinga's name does not fea...
# 4          mcmatata1   @kiraguisaac_22: H.E Uhuru kenyatta could not...
# ..               ...                                                ...
# 195    zalendomartin   @HezMureithi: KENYA DECIDES🗳 2022\nWhich Team...
# 196  Raphael14822774   @kuriasolomonK: If you will vote for Raila Od...
# 197        Kamangara   @HezMureithi: KENYA DECIDES🗳 2022\nWhich Team...
# 198      OsoroYobesi  Kenyans should be told that it's also unethica...
# 199           RasKE_   @pascalo_pascal: @RasKE_ How comes raila neve...
#
#                                           clean_tweets  \
# 0    : Uhuru associating himself with Raila and Mar...
# 1    : BREAKING: A group of Posh Luos, who told us ...
# 2    : In the Laws of power ,Never try to outshine ...
# 3    : Raila Odinga's name does not feature in the ...
# 4    : H.E Uhuru kenyatta could not afford time for...
# ..                                                 ...
# 195  : KENYA DECIDES Which Team are You going to VO...
# 196  : If you will vote for Raila Odinga because he...
# 197  : KENYA DECIDES Which Team are You going to VO...
# 198  Kenyans should be told that it's also unethica...
# 199  : How comes raila never won and the way he was...
#
#                                             POS tagged
# 0    [(:, None), (Uhuru, n), (associating, None), (...
# 1    [(:, None), (BREAKING, n), (:, None), (group, ...
# 2    [(:, None), (Laws, n), (power, n), (,, None), ...
# 3    [(:, None), (Raila, n), (Odinga, n), ('s, None...
# 4    [(:, None), (H.E, n), (Uhuru, n), (kenyatta, n...
# ..                                                 ...
# 195  [(:, None), (KENYA, n), (DECIDES, n), (Team, n...
# 196  [(:, None), (vote, None), (Raila, n), (Odinga,...
# 197  [(:, None), (KENYA, n), (DECIDES, n), (Team, n...
# 198  [(Kenyans, n), (told, None), ('s, None), (also...
# 199  [(:, None), (comes, None), (raila, r), (never,...
#
# [200 rows x 4 columns]

# %%
# Lemmatization
df['Lemma'] = df['POS tagged'].apply(lambda x: lemmatize(x))
df.head()
# Out:
#              User                                               Data  \
# 0  Wilson38573694   @Kenyans: Uhuru associating himself with Rail...
# 1      BernetOjay   @gabrieloguda: BREAKING: A group of Posh Luos...
# 2      _John_Best   @FrankMtetezi: In the 48 Laws of power ,Never...
# 3       Kips_Manu   @DavisKRuto: Raila Odinga's name does not fea...
# 4       mcmatata1   @kiraguisaac_22: H.E Uhuru kenyatta could not...
#
#                                         clean_tweets  \
# 0  : Uhuru associating himself with Raila and Mar...
# 1  : BREAKING: A group of Posh Luos, who told us ...
# 2  : In the Laws of power ,Never try to outshine ...
# 3  : Raila Odinga's name does not feature in the ...
# 4  : H.E Uhuru kenyatta could not afford time for...
#
#                                           POS tagged  \
# 0  [(:, None), (Uhuru, n), (associating, None), (...
# 1  [(:, None), (BREAKING, n), (:, None), (group, ...
# 2  [(:, None), (Laws, n), (power, n), (,, None), ...
# 3  [(:, None), (Raila, n), (Odinga, n), ('s, None...
# 4  [(:, None), (H.E, n), (Uhuru, n), (kenyatta, n...
#
#                                                Lemma
# 0    : Uhuru associating Raila Martha weakens Azi...
# 1    : BREAKING : group Posh Luos , told us Uhuru...
# 2    : Laws power , Never try outshine master , P...
# 3    : Raila Odinga 's name feature protocol toda...
# 4    : H.E Uhuru kenyatta could afford time next ...

# %% [markdown]
# ## Get only english text

# %%
df['language'] = df['clean_tweets'].apply(lambda x: get_language(x) if x.strip()!="" else "")
df = df[df['language']=='en'].reset_index(drop=True)
df.drop('language', axis=1)
df
# Out:
#                 User                                               Data  \
# 0     Wilson38573694   @Kenyans: Uhuru associating himself with Rail...
# 1         BernetOjay   @gabrieloguda: BREAKING: A group of Posh Luos...
# 2         _John_Best   @FrankMtetezi: In the 48 Laws of power ,Never...
# 3          Kips_Manu   @DavisKRuto: Raila Odinga's name does not fea...
# 4          mcmatata1   @kiraguisaac_22: H.E Uhuru kenyatta could not...
# ..               ...                                                ...
# 191    zalendomartin   @HezMureithi: KENYA DECIDES🗳 2022\nWhich Team...
# 192  Raphael14822774   @kuriasolomonK: If you will vote for Raila Od...
# 193        Kamangara   @HezMureithi: KENYA DECIDES🗳 2022\nWhich Team...
# 194      OsoroYobesi  Kenyans should be told that it's also unethica...
# 195           RasKE_   @pascalo_pascal: @RasKE_ How comes raila neve...
#
#                                           clean_tweets  \
# 0    : Uhuru associating himself with Raila and Mar...
# 1    : BREAKING: A group of Posh Luos, who told us ...
# 2    : In the Laws of power ,Never try to outshine ...
# 3    : Raila Odinga's name does not feature in the ...
# 4    : H.E Uhuru kenyatta could not afford time for...
# ..                                                 ...
# 191  : KENYA DECIDES Which Team are You going to VO...
# 192  : If you will vote for Raila Odinga because he...
# 193  : KENYA DECIDES Which Team are You going to VO...
# 194  Kenyans should be told that it's also unethica...
# 195  : How comes raila never won and the way he was...
#
#                                             POS tagged  \
# 0    [(:, None), (Uhuru, n), (associating, None), (...
# 1    [(:, None), (BREAKING, n), (:, None), (group, ...
# 2    [(:, None), (Laws, n), (power, n), (,, None), ...
# 3    [(:, None), (Raila, n), (Odinga, n), ('s, None...
# 4    [(:, None), (H.E, n), (Uhuru, n), (kenyatta, n...
# ..                                                 ...
# 191  [(:, None), (KENYA, n), (DECIDES, n), (Team, n...
# 192  [(:, None), (vote, None), (Raila, n), (Odinga,...
# 193  [(:, None), (KENYA, n), (DECIDES, n), (Team, n...
# 194  [(Kenyans, n), (told, None), ('s, None), (also...
# 195  [(:, None), (comes, None), (raila, r), (never,...
#
#                                                  Lemma language
# 0      : Uhuru associating Raila Martha weakens Azi...       en
# 1      : BREAKING : group Posh Luos , told us Uhuru...       en
# 2      : Laws power , Never try outshine master , P...       en
# 3      : Raila Odinga 's name feature protocol toda...       en
# 4      : H.E Uhuru kenyatta could afford time next ...       en
# ..                                                 ...      ...
# 191    : KENYA DECIDES Team going VOTE August th Su...       en
# 192    : vote Raila Odinga picked Martha Karua runn...       en
# 193    : KENYA DECIDES Team going VOTE August th Su...       en
# 194    Kenyans told 's also unethical swear people ...       en
# 195                : comes raila never way mistreaated       en
#
# [196 rows x 6 columns]

# %% [markdown]
# ## Named Entity Recognition

# %%
import streamlit as st
import spacy
from collections import  Counter
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# visualise extracted NER count and extract NERs
def plot_named_entity_barchart(text):
    nlp = spacy.load("political_ner_model")
    
    def _get_ner(text):
        doc=nlp(text)
        return [X.label_ for X in doc.ents]
    
    ent=text.apply(lambda x : _get_ner(x))
    ent=[x for sub in ent for x in sub]
    counter=Counter(ent)
    count=counter.most_common()
    
    x,y=map(list,zip(*count))

    # get unique list elements to pass to
    # streamlit app for dropdown options
    ent = set(ent)
    
    return ent, x, y

# %%
ent, x, y = plot_named_entity_barchart(df['clean_tweets'])

# %%
#list(ent)
print(y)
# Out:
# [453, 42]

# %%
sns.barplot(y,x).set_title(ent)
# Out:
# c:\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, "{'POLITICIAN', 'POLITICAL_PARTY'}")

# %% [markdown]
# ## Find Words Similarity

# %%
from fuzzywuzzy import fuzz

# %%
def get_ruto_similarity_ratio(name):
    """ This is a method to determine how similar a name mentioned is to the name of Ruto. 
    For example someone might write Rutot by mistake hence we need to record this mention"""
    
    ruto = 'william ruto'
    ratio = 0
    if name != 'Raila':
        ratio = fuzz.partial_ratio(ruto.lower(), name.lower())
    return int(ratio)

# %%
def get_raila_similarity_ratio(name):
    """ This is a method to determine how similar a name mentioned is to the name of Raila. 
    For example someone might write Railal by mistake hence we need to record this mention"""
    
    raila = 'raila amolo odinga'
    ratio = 0
    if name != 'Ruto':
        ratio = fuzz.partial_ratio(raila.lower(), name.lower())
    return int(ratio)

# %%
def get_similar_candidate_names(names):
    """
    This is a method to get get the different names of politicians and return only one common name. 
    For example Raila may be known as Baba, Odinga, etc. We convert all these names to Raila.
    """
    
    ruto = ["ruto", 'william', "deputy", "wSR", "william samoei ruto", 'DP']
    raila=["raila amolo odinga","raila", "odinga", "baba", "rao","kitendawili"]
    for i in range(len(names)):
        if (names[i].lower() in ruto) or (get_ruto_similarity_ratio(names[i].lower()) > 50):
            names[i] = 'Ruto'

        elif (names[i].lower() in raila) or (get_raila_similarity_ratio(names[i].lower()) >50):
            names[i] = 'Raila'
    return names

# %%
# visualise tokens per entity
def plot_most_common_named_entity_barchart(text, entity):
    '''
    plots a graph of the top 10 most mentioned politicians 
    '''
   
    nlp = spacy.load("political_ner_model")
    
    #get the text mentioning the entity
    def _get_ner(text,ent):
        doc=nlp(text)
        return [X.text for X in doc.ents if X.label_ == ent]
    
    entity_filtered=text.apply(lambda x: _get_ner(x,entity))
    entity_filtered=[i for x in entity_filtered for i in x]
    entity_filtered = get_similar_candidate_names(entity_filtered)
    
    #get the number of times the name is mentioned
    counter=Counter(entity_filtered)
    
    #separate into name and the number of mentions for plotting
    x,y=map(list,zip(*counter.most_common(10)))
    
    return (x,y)
           
  
    #st.pyplot()

# %%
#graph plotting
x, y = plot_most_common_named_entity_barchart(df['clean_tweets'], "POLITICIAN")
fig, ax = plt.subplots()
sns.barplot(y,x).set_title('POLITICIAN')
# Out:
# c:\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'POLITICIAN')

# %%
top3 = x[:3]
top3
# Out:
# ['Ruto', 'Uhuru', 'Raila']

# %% [markdown]
# ## Geta clean dataframe for text analysis

# %%
fin_data= pd.DataFrame(df[['Data']])

# %% [markdown]
# ## Named Entity Recognition

# %%
nlp = spacy.load("political_ner_model")
fin_data["tags"] = df["Data"].apply(lambda x: [(tag.text, tag.label_) for tag in nlp(x).ents])
fin_data[0:50]
# Out:
#                                                  Data  \
# 0    @Kenyans: Uhuru associating himself with Rail...
# 1    @gabrieloguda: BREAKING: A group of Posh Luos...
# 2    @FrankMtetezi: In the 48 Laws of power ,Never...
# 3    @DavisKRuto: Raila Odinga's name does not fea...
# 4    @kiraguisaac_22: H.E Uhuru kenyatta could not...
# 5    @StateHouseKenya: 2/2\n...that was attended b...
# 6    @GeorgesRuto: Dp Ruto\nUhuru Kenyatta\nWho wi...
# 7    @NationAfrica: PS Kibicho: Intelligence repor...
# 8    @Its_Wachiuri: Who will you choose as your in...
# 9    @StateHouseKenya: 2/2\n...that was attended b...
# 10   @silasnjura: Kikuyu have never voted for Rail...
# 11  @PeterMa91276028 @Hillary_moro @NahashonKimemi...
# 12   @CharleneRuto: In whose hands do you think Ke...
# 13   @GeorgesRuto: Dp Ruto\nUhuru Kenyatta\nWho wi...
# 14   @GeorgesRuto: Dp Ruto\nUhuru Kenyatta\nWho wi...
# 15  @RephaelTuju @MarthaKarua @RailaOdinga Cs much...
# 16   @SilviaWangeci2: Raila Odinga is NOT Trending...
# 17   @SilviaWangeci2: Raila Odinga is NOT Trending...
# 18   @bonifacemwangi: If my happiness for Martha K...
# 19  @ahmednasirlaw Mr Ngamia, I want to see what y...
# 20  @ItsMutai As it is, both are in his black book...
# 21   @KiigenKoech: YES! I agree. BABA Rt. Hon. RAI...
# 22   @FrankMtetezi: In the 48 Laws of power ,Never...
# 23  Most of the Kikuyus supporting Martha Karua ho...
# 24   @josphatkipk: @MigunaMiguna @ODPP_KE Raila Od...
# 25   @Its_Wachiuri: Who will you choose as your in...
# 26   @ItsMutai: Raila Odinga really doesn't care s...
# 27   @mwaurq: KENYA DECIDES🗳 2022\nWhich Team are ...
# 28   @ItsMutai: The move by Uhuru Kenyatta to take...
# 29   @JymoohMuks: Support your preferred candidate...
# 30  Clash of the titans!\n\nTwo rival clubs clash ...
# 31   @FrankMtetezi: In the 48 Laws of power ,Never...
# 32   @GeorgesRuto: Dp Ruto\nUhuru Kenyatta\nWho wi...
# 33  @hellenjeriKe If you hear UDA supporters defen...
# 34  @RephaelTuju @RailaOdinga So 2017 Raila win th...
# 35  @WilliamsRuto @Aaroncheruiyot @KiarieJohn @Mwa...
# 36   @FrankMtetezi: In the 48 Laws of power ,Never...
# 37   @Kenyan_Report: Who is the next commander in ...
# 38   @mwaurq: KENYA DECIDES🗳 2022\nWhich Team are ...
# 39   @KiigenKoech: RAILA ODINGA is an INSTITUTION!...
# 40  @smutoro Remember some time back in Central (n...
# 41   @JymoohMuks: Whom do you think can handle the...
# 42   @GitobuImanyara: We are now officially in the...
# 43   @HezMureithi: KENYA DECIDES🗳 2022\nWhich Team...
# 44  @RephaelTuju @RailaOdinga Raila has lost elect...
# 45  @MigunaMiguna @StateHouseKenya @RailaOdinga Ra...
# 46  @OleItumbi Raila is being weakened and other s...
# 47   @Kenyan_Report: Who is the next commander in ...
# 48   @GeorgesRuto: Dp Ruto\nUhuru Kenyatta\nWho wi...
# 49   @FrankMtetezi: In the 48 Laws of power ,Never...
#
#                                                  tags
# 0   [(Uhuru, POLITICIAN), (Raila, POLITICIAN), (Ma...
# 1   [(Uhuru, POLITICIAN), (Raila, POLITICIAN), (Od...
# 2       [(Uhuru, POLITICIAN), (Kenyatta, POLITICIAN)]
# 3   [(Raila, POLITICIAN), (Odinga, POLITICIAN), (D...
# 4                               [(Uhuru, POLITICIAN)]
# 5                              [(Julius, POLITICIAN)]
# 6   [(@GeorgesRuto, POLITICIAN), (Ruto, POLITICIAN...
# 7                               [(Raila, POLITICIAN)]
# 8   [(Ruto, POLITICIAN), (Raila, POLITICIAN), (Odi...
# 9                              [(Julius, POLITICIAN)]
# 10  [(Raila, POLITICIAN), (Odinga, POLITICIAN), (R...
# 11  [(Rigathi, POLITICIAN), (Kikuyus, POLITICIAN),...
# 12  [(@CharleneRuto, POLITICIAN), (Raila, POLITICI...
# 13  [(@GeorgesRuto, POLITICIAN), (Ruto, POLITICIAN...
# 14  [(@GeorgesRuto, POLITICIAN), (Ruto, POLITICIAN...
# 15  [(Raila, POLITICIAN), (-Raila, POLITICIAN), (R...
# 16  [(Raila, POLITICIAN), (Odinga, POLITICIAN), (M...
# 17  [(Raila, POLITICIAN), (Odinga, POLITICIAN), (M...
# 18                             [(Martha, POLITICIAN)]
# 19                              [(Raila, POLITICIAN)]
# 20  [(Ruto, POLITICIAN), (Raila, POLITICIAN), (Pet...
# 21                                  [(4, POLITICIAN)]
# 22      [(Uhuru, POLITICIAN), (Kenyatta, POLITICIAN)]
# 23  [(Kikuyus, POLITICIAN), (Martha, POLITICIAN), ...
# 24  [(Raila, POLITICIAN), (Odinga, POLITICIAN), (M...
# 25  [(Ruto, POLITICIAN), (Raila, POLITICIAN), (Odi...
# 26        [(Raila, POLITICIAN), (Odinga, POLITICIAN)]
# 27  [(KENYA, POLITICAL_PARTY), (Uhuru, POLITICIAN)...
# 28  [(Uhuru, POLITICIAN), (Kenyatta, POLITICIAN), ...
# 29        [(Raila, POLITICIAN), (Odinga, POLITICIAN)]
# 30  [(Raila, POLITICIAN), (Odinga, POLITICIAN), (A...
# 31      [(Uhuru, POLITICIAN), (Kenyatta, POLITICIAN)]
# 32  [(@GeorgesRuto, POLITICIAN), (Ruto, POLITICIAN...
# 33                           [(UDA, POLITICAL_PARTY)]
# 34                              [(Raila, POLITICIAN)]
# 35  [(@WilliamsRuto, POLITICIAN), (Raila, POLITICI...
# 36      [(Uhuru, POLITICIAN), (Kenyatta, POLITICIAN)]
# 37  [(Raila, POLITICIAN), (Odinga, POLITICIAN), (R...
# 38  [(KENYA, POLITICAL_PARTY), (Uhuru, POLITICIAN)...
# 39                               [(Baba, POLITICIAN)]
# 40                              [(Raila, POLITICIAN)]
# 41  [(William, POLITICIAN), (Ruto, POLITICIAN), (R...
# 42                                                 []
# 43  [(KENYA, POLITICAL_PARTY), (Uhuru, POLITICIAN)...
# 44                              [(Raila, POLITICIAN)]
# 45                              [(Raila, POLITICIAN)]
# 46                              [(Raila, POLITICIAN)]
# 47  [(Raila, POLITICIAN), (Odinga, POLITICIAN), (R...
# 48  [(@GeorgesRuto, POLITICIAN), (Ruto, POLITICIAN...
# 49      [(Uhuru, POLITICIAN), (Kenyatta, POLITICIAN)]

# %%
def get_politician_names(names):
    '''
    This method gets the politicians mentioned in each comments and puts them in a separate column
    it returns alist of all the politicians mentioned in each comment. 
    The set method is used to remove repetitive mentions
    '''
    pol_names = []
    for i in range(len(names)):
        if names[i][1] == 'POLITICIAN':
            pol_names.append(names[i][0])
            
    pol_names = get_similar_candidate_names(pol_names)
    pol_names = list(set(pol_names))
    return pol_names

# %%
fin_data["Politicians"] = fin_data["tags"].apply(lambda x: get_politician_names(x))
fin_data
# Out:
#                                                   Data  \
# 0     @Kenyans: Uhuru associating himself with Rail...
# 1     @gabrieloguda: BREAKING: A group of Posh Luos...
# 2     @FrankMtetezi: In the 48 Laws of power ,Never...
# 3     @DavisKRuto: Raila Odinga's name does not fea...
# 4     @kiraguisaac_22: H.E Uhuru kenyatta could not...
# ..                                                 ...
# 191   @HezMureithi: KENYA DECIDES🗳 2022\nWhich Team...
# 192   @kuriasolomonK: If you will vote for Raila Od...
# 193   @HezMureithi: KENYA DECIDES🗳 2022\nWhich Team...
# 194  Kenyans should be told that it's also unethica...
# 195   @pascalo_pascal: @RasKE_ How comes raila neve...
#
#                                                   tags            Politicians
# 0    [(Uhuru, POLITICIAN), (Raila, POLITICIAN), (Ma...  [Martha, Ruto, Uhuru]
# 1    [(Uhuru, POLITICIAN), (Raila, POLITICIAN), (Od...   [Ruto, Uhuru, Raila]
# 2        [(Uhuru, POLITICIAN), (Kenyatta, POLITICIAN)]      [Kenyatta, Uhuru]
# 3    [(Raila, POLITICIAN), (Odinga, POLITICIAN), (D...     [Ruto, Raila, Day]
# 4                                [(Uhuru, POLITICIAN)]                [Uhuru]
# ..                                                 ...                    ...
# 191  [(KENYA, POLITICAL_PARTY), (Uhuru, POLITICIAN)...      [Kenyatta, Uhuru]
# 192  [(Raila, POLITICIAN), (Odinga, POLITICIAN), (M...  [Martha, Ruto, Raila]
# 193  [(KENYA, POLITICAL_PARTY), (Uhuru, POLITICIAN)...      [Kenyatta, Uhuru]
# 194  [(Uhuru, POLITICIAN), (Ruto, POLITICIAN), (Rai...          [Ruto, Uhuru]
# 195                                                 []                     []
#
# [196 rows x 3 columns]

# %% [markdown]
# ## Sentiment Analysis

# %%
fin_data['Vader_Sentiment'] = fin_data['Data'].apply(lambda x: vaderSentimentAnalysis(x))
fin_data['Vader_Analysis'] = fin_data['Vader_Sentiment'].apply(lambda x: vader_analysis(x))
fin_data[1:50]
# Out:
#                                                  Data  \
# 1    @gabrieloguda: BREAKING: A group of Posh Luos...
# 2    @FrankMtetezi: In the 48 Laws of power ,Never...
# 3    @DavisKRuto: Raila Odinga's name does not fea...
# 4    @kiraguisaac_22: H.E Uhuru kenyatta could not...
# 5    @StateHouseKenya: 2/2\n...that was attended b...
# 6    @GeorgesRuto: Dp Ruto\nUhuru Kenyatta\nWho wi...
# 7    @NationAfrica: PS Kibicho: Intelligence repor...
# 8    @Its_Wachiuri: Who will you choose as your in...
# 9    @StateHouseKenya: 2/2\n...that was attended b...
# 10   @silasnjura: Kikuyu have never voted for Rail...
# 11  @PeterMa91276028 @Hillary_moro @NahashonKimemi...
# 12   @CharleneRuto: In whose hands do you think Ke...
# 13   @GeorgesRuto: Dp Ruto\nUhuru Kenyatta\nWho wi...
# 14   @GeorgesRuto: Dp Ruto\nUhuru Kenyatta\nWho wi...
# 15  @RephaelTuju @MarthaKarua @RailaOdinga Cs much...
# 16   @SilviaWangeci2: Raila Odinga is NOT Trending...
# 17   @SilviaWangeci2: Raila Odinga is NOT Trending...
# 18   @bonifacemwangi: If my happiness for Martha K...
# 19  @ahmednasirlaw Mr Ngamia, I want to see what y...
# 20  @ItsMutai As it is, both are in his black book...
# 21   @KiigenKoech: YES! I agree. BABA Rt. Hon. RAI...
# 22   @FrankMtetezi: In the 48 Laws of power ,Never...
# 23  Most of the Kikuyus supporting Martha Karua ho...
# 24   @josphatkipk: @MigunaMiguna @ODPP_KE Raila Od...
# 25   @Its_Wachiuri: Who will you choose as your in...
# 26   @ItsMutai: Raila Odinga really doesn't care s...
# 27   @mwaurq: KENYA DECIDES🗳 2022\nWhich Team are ...
# 28   @ItsMutai: The move by Uhuru Kenyatta to take...
# 29   @JymoohMuks: Support your preferred candidate...
# 30  Clash of the titans!\n\nTwo rival clubs clash ...
# 31   @FrankMtetezi: In the 48 Laws of power ,Never...
# 32   @GeorgesRuto: Dp Ruto\nUhuru Kenyatta\nWho wi...
# 33  @hellenjeriKe If you hear UDA supporters defen...
# 34  @RephaelTuju @RailaOdinga So 2017 Raila win th...
# 35  @WilliamsRuto @Aaroncheruiyot @KiarieJohn @Mwa...
# 36   @FrankMtetezi: In the 48 Laws of power ,Never...
# 37   @Kenyan_Report: Who is the next commander in ...
# 38   @mwaurq: KENYA DECIDES🗳 2022\nWhich Team are ...
# 39   @KiigenKoech: RAILA ODINGA is an INSTITUTION!...
# 40  @smutoro Remember some time back in Central (n...
# 41   @JymoohMuks: Whom do you think can handle the...
# 42   @GitobuImanyara: We are now officially in the...
# 43   @HezMureithi: KENYA DECIDES🗳 2022\nWhich Team...
# 44  @RephaelTuju @RailaOdinga Raila has lost elect...
# 45  @MigunaMiguna @StateHouseKenya @RailaOdinga Ra...
# 46  @OleItumbi Raila is being weakened and other s...
# 47   @Kenyan_Report: Who is the next commander in ...
# 48   @GeorgesRuto: Dp Ruto\nUhuru Kenyatta\nWho wi...
# 49   @FrankMtetezi: In the 48 Laws of power ,Never...
#
#                                                  tags  \
# 1   [(Uhuru, POLITICIAN), (Raila, POLITICIAN), (Od...
# 2       [(Uhuru, POLITICIAN), (Kenyatta, POLITICIAN)]
# 3   [(Raila, POLITICIAN), (Odinga, POLITICIAN), (D...
# 4                               [(Uhuru, POLITICIAN)]
# 5                              [(Julius, POLITICIAN)]
# 6   [(@GeorgesRuto, POLITICIAN), (Ruto, POLITICIAN...
# 7                               [(Raila, POLITICIAN)]
# 8   [(Ruto, POLITICIAN), (Raila, POLITICIAN), (Odi...
# 9                              [(Julius, POLITICIAN)]
# 10  [(Raila, POLITICIAN), (Odinga, POLITICIAN), (R...
# 11  [(Rigathi, POLITICIAN), (Kikuyus, POLITICIAN),...
# 12  [(@CharleneRuto, POLITICIAN), (Raila, POLITICI...
# 13  [(@GeorgesRuto, POLITICIAN), (Ruto, POLITICIAN...
# 14  [(@GeorgesRuto, POLITICIAN), (Ruto, POLITICIAN...
# 15  [(Raila, POLITICIAN), (-Raila, POLITICIAN), (R...
# 16  [(Raila, POLITICIAN), (Odinga, POLITICIAN), (M...
# 17  [(Raila, POLITICIAN), (Odinga, POLITICIAN), (M...
# 18                             [(Martha, POLITICIAN)]
# 19                              [(Raila, POLITICIAN)]
# 20  [(Ruto, POLITICIAN), (Raila, POLITICIAN), (Pet...
# 21                                  [(4, POLITICIAN)]
# 22      [(Uhuru, POLITICIAN), (Kenyatta, POLITICIAN)]
# 23  [(Kikuyus, POLITICIAN), (Martha, POLITICIAN), ...
# 24  [(Raila, POLITICIAN), (Odinga, POLITICIAN), (M...
# 25  [(Ruto, POLITICIAN), (Raila, POLITICIAN), (Odi...
# 26        [(Raila, POLITICIAN), (Odinga, POLITICIAN)]
# 27  [(KENYA, POLITICAL_PARTY), (Uhuru, POLITICIAN)...
# 28  [(Uhuru, POLITICIAN), (Kenyatta, POLITICIAN), ...
# 29        [(Raila, POLITICIAN), (Odinga, POLITICIAN)]
# 30  [(Raila, POLITICIAN), (Odinga, POLITICIAN), (A...
# 31      [(Uhuru, POLITICIAN), (Kenyatta, POLITICIAN)]
# 32  [(@GeorgesRuto, POLITICIAN), (Ruto, POLITICIAN...
# 33                           [(UDA, POLITICAL_PARTY)]
# 34                              [(Raila, POLITICIAN)]
# 35  [(@WilliamsRuto, POLITICIAN), (Raila, POLITICI...
# 36      [(Uhuru, POLITICIAN), (Kenyatta, POLITICIAN)]
# 37  [(Raila, POLITICIAN), (Odinga, POLITICIAN), (R...
# 38  [(KENYA, POLITICAL_PARTY), (Uhuru, POLITICIAN)...
# 39                               [(Baba, POLITICIAN)]
# 40                              [(Raila, POLITICIAN)]
# 41  [(William, POLITICIAN), (Ruto, POLITICIAN), (R...
# 42                                                 []
# 43  [(KENYA, POLITICAL_PARTY), (Uhuru, POLITICIAN)...
# 44                              [(Raila, POLITICIAN)]
# 45                              [(Raila, POLITICIAN)]
# 46                              [(Raila, POLITICIAN)]
# 47  [(Raila, POLITICIAN), (Odinga, POLITICIAN), (R...
# 48  [(@GeorgesRuto, POLITICIAN), (Ruto, POLITICIAN...
# 49      [(Uhuru, POLITICIAN), (Kenyatta, POLITICIAN)]
#
#                               Politicians  Vader_Sentiment Vader_Analysis
# 1                    [Ruto, Uhuru, Raila]           0.2023       Positive
# 2                       [Kenyatta, Uhuru]           0.0000        Neutral
# 3                      [Ruto, Raila, Day]           0.0000        Neutral
# 4                                 [Uhuru]           0.0000        Neutral
# 5                                [Julius]           0.2732       Positive
# 6   [Kenyatta, Ruto, Uhuru, @GeorgesRuto]           0.0000        Neutral
# 7                                  [Ruto]           0.7845       Positive
# 8                           [Ruto, Raila]           0.7717       Positive
# 9                                [Julius]           0.2732       Positive
# 10                          [Ruto, Raila]           0.0000        Neutral
# 11               [Rigathi, Ruto, Kikuyus]           0.3612       Positive
# 12                  [@CharleneRuto, Ruto]           0.8842       Positive
# 13  [Kenyatta, Ruto, Uhuru, @GeorgesRuto]           0.0000        Neutral
# 14  [Kenyatta, Ruto, Uhuru, @GeorgesRuto]           0.0000        Neutral
# 15    [1st, Uhuru, Kenyatta, Ruto, Raila]           0.5859       Positive
# 16           [Martha, Ruto, Raila, Uhuru]           0.0000        Neutral
# 17           [Martha, Ruto, Raila, Uhuru]           0.0000        Neutral
# 18                               [Martha]           0.7783       Positive
# 19                                 [Ruto]           0.9731       Positive
# 20                 [Peter, Ruto, Kenneth]          -0.0516       Negative
# 21                                    [4]           0.8252       Positive
# 22                      [Kenyatta, Uhuru]           0.0000        Neutral
# 23             [Ruto, Martha, Kikuyus, 1]           0.8519       Positive
# 24           [Martha, Ruto, Raila, Uhuru]           0.0000        Neutral
# 25                          [Ruto, Raila]           0.7717       Positive
# 26                          [Ruto, Raila]          -0.4416       Negative
# 27                      [Kenyatta, Uhuru]           0.4939       Positive
# 28         [Ruto, Kenyatta, Uhuru, Raila]           0.0000        Neutral
# 29                          [Ruto, Raila]           0.8555       Positive
# 30           [Martha, Ruto, Raila, Uhuru]           0.7809       Positive
# 31                      [Kenyatta, Uhuru]           0.0000        Neutral
# 32  [Kenyatta, Ruto, Uhuru, @GeorgesRuto]           0.0000        Neutral
# 33                                     []           0.4404       Positive
# 34                                 [Ruto]           0.9506       Positive
# 35                          [Ruto, Raila]           0.0000        Neutral
# 36                      [Kenyatta, Uhuru]           0.0000        Neutral
# 37                          [Ruto, Raila]           0.7717       Positive
# 38                      [Kenyatta, Uhuru]           0.4939       Positive
# 39                                [Raila]          -0.4003       Negative
# 40                                 [Ruto]          -0.2411       Negative
# 41                          [Ruto, Raila]           0.7717       Positive
# 42                                     []           0.3182       Positive
# 43                      [Kenyatta, Uhuru]           0.4939       Positive
# 44                                 [Ruto]          -0.3182       Negative
# 45                                 [Ruto]           0.0000        Neutral
# 46                                 [Ruto]          -0.6597       Negative
# 47                          [Ruto, Raila]           0.7717       Positive
# 48  [Kenyatta, Ruto, Uhuru, @GeorgesRuto]           0.0000        Neutral
# 49                      [Kenyatta, Uhuru]           0.0000        Neutral

# %%
def get_politician_sentiment(politician, sentiment, df):
    '''
    Gets the number of sentiments for a particular politician. 
    Pass in the name of the politician and the sentiment you want to identify
    '''
    count = 0
    for i in range(len(df)):
        for n in df['Politicians'].iloc[i]:
            if n == politician and df['Vader_Analysis'].iloc[i] == sentiment:
                count += 1

    return count

# %%
def get_sentiment_count(sentiment, df):
    '''
    get the number of sentiments for the top 3 politicians.
    pass in the sentiment you want to count.
    returns a list of the count of sentiments you passed in for all the politicians
    '''
    sentiment_count = []
    for pol in top3:
        counts = get_politician_sentiment(pol, sentiment, df)
        sentiment_count.append(counts)
    return sentiment_count

# %%
negative_sentiments = get_sentiment_count('Negative', fin_data)
positive_sentiments = get_sentiment_count('Positive', fin_data)
neutral_sentiments = get_sentiment_count('Neutral', fin_data)


print(negative_sentiments, '\n', positive_sentiments, '\n', neutral_sentiments)
# Out:
# [18, 6, 7]
#  [68, 26, 41]
#  [50, 53, 19]

# %%
def plot_sentiment_analysis(sentiment, title, top3):
    '''
    Plot the graphs for the top 3 candidates with their sentiment variations
    '''
    y = np.array(sentiment)
    myexplode = [0.1, 0, 0]
    fig, ax = plt.subplots(figsize = (10,6))
    ax.grid(False)
    plt.style.use('ggplot')
    plt.pie(y, labels = top3, explode = myexplode,shadow = True, autopct='%1.0f%%')
    plt.legend()
    fig.set_facecolor('white')
    plt.title(title)
    plt.show()

# %%
plot_sentiment_analysis(negative_sentiments, 'NEGATIVE SENTIMENT ANALYSIS', top3)

# %%
plot_sentiment_analysis(positive_sentiments, 'POSITIVE SENTIMENT ANALYSIS', top3)

# %%
plot_sentiment_analysis(neutral_sentiments, 'NEUTRAL SENTIMENT ANALYSIS', top3)

# %%
vd_counts = fin_data["Vader_Analysis"].value_counts()
vd_counts
# Out:
# Positive    104
# Neutral      69
# Negative     23
# Name: Vader_Analysis, dtype: int64

# %% [markdown]
# # HATESPEECH DETECTION

# %% [markdown]
# ## Model Training

# %%
import os
#to get the current working directory
directory = os.getcwd()
print(directory)
#Importing the dataset
dataset = pd.read_csv(directory +'\data_sets\\hate-speech-and-offensive-language-dataset\\labeled_data.csv')
dataset.info()
ke_dataset = pd.read_csv(directory +'\data_sets\\hate-speech-kenya\\HateSpeechKEN.csv')
data_train = pd.read_csv(directory +'\data_sets\\twitter-sentiment-analysis-hatred-speech\\train.csv')
# Out:
# C:\Users\NYAM\Desktop\Main Project\Example models\PolitcalAnalysis-data-visualisation
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24783 entries, 0 to 24782
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          24783 non-null  int64
#  1   count               24783 non-null  int64
#  2   hate_speech         24783 non-null  int64
#  3   offensive_language  24783 non-null  int64
#  4   neither             24783 non-null  int64
#  5   class               24783 non-null  int64
#  6   tweet               24783 non-null  object
# dtypes: int64(6), object(1)
# memory usage: 1.3+ MB

# %%
dataset.drop(['Unnamed: 0','count','hate_speech','offensive_language','neither'],axis=1,inplace=True)
ke_dataset.drop(['count','hate_speech','offensive_language','neither'],axis=1,inplace=True)
data_train.drop('id', axis=1,inplace=True)

# %%
dataset["class"].replace({0: 1}, inplace=True)
ke_dataset["class"].replace({0: 1}, inplace=True)

# %%
dataset["class"].replace({2: 0}, inplace=True)
ke_dataset["class"].replace({2: 0}, inplace=True)
dataset.rename(columns ={'class':'label'}, inplace = True)
ke_dataset.rename(columns ={'class':'label'}, inplace = True)

# %%
frame=[data_train,dataset,ke_dataset[25500::]]
df = pd.concat(frame)
df.head(5)
# Out:
#    label                                              tweet
# 0      0   @user when a father is dysfunctional and is s...
# 1      0  @user @user thanks for #lyft credit i can't us...
# 2      0                                bihday your majesty
# 3      0  #model   i love u take with u all the time in ...
# 4      0             factsguide: society now    #motivation

# %%
df['tweet']=df['tweet'].apply(clean_text)
df.head()
df.shape
# Out:
# (81420, 2)

# %%
X = df['tweet']
y = df['label']

# %%
#splitting the dataset into Trainign and testing data set
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
count = CountVectorizer(stop_words='english', ngram_range=(1,5),max_features=2000)
x_train_vectorizer=count.fit_transform(X_train)
x_test_vectorizer=count.transform(X_test)
x_train_vectorizer.toarray()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18520/977439467.py in <module>
#       2 x_train_vectorizer=count.fit_transform(X_train)
#       3 x_test_vectorizer=count.transform(X_test)
# ----> 4 x_train_vectorizer.toarray()
#
# c:\python39\lib\site-packages\scipy\sparse\compressed.py in toarray(self, order, out)
#    1029         if out is None and order is None:
#    1030             order = self._swap('cf')[0]
# -> 1031         out = self._process_toarray_args(order, out)
#    1032         if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1033             raise ValueError('Output array must be C or F contiguous')
#
# c:\python39\lib\site-packages\scipy\sparse\base.py in _process_toarray_args(self, order, out)
#    1200             return out
#    1201         else:
# -> 1202             return np.zeros(self.shape, dtype=self.dtype, order=order)
#    1203
#    1204
#
# MemoryError: Unable to allocate 932. MiB for an array with shape (61065, 2000) and data type int64

# %%
#
tfidf = TfidfTransformer()

x_train_tfidf = tfidf.fit_transform(x_train_vectorizer)

x_train_tfidf.toarray()
x_test_tfidf = tfidf.transform(x_test_vectorizer)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18520/1562253348.py in <module>
#       4 x_train_tfidf = tfidf.fit_transform(x_train_vectorizer)
#       5
# ----> 6 x_train_tfidf.toarray()
#       7 x_test_tfidf = tfidf.transform(x_test_vectorizer)
#
# c:\python39\lib\site-packages\scipy\sparse\compressed.py in toarray(self, order, out)
#    1029         if out is None and order is None:
#    1030             order = self._swap('cf')[0]
# -> 1031         out = self._process_toarray_args(order, out)
#    1032         if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1033             raise ValueError('Output array must be C or F contiguous')
#
# c:\python39\lib\site-packages\scipy\sparse\base.py in _process_toarray_args(self, order, out)
#    1200             return out
#    1201         else:
# -> 1202             return np.zeros(self.shape, dtype=self.dtype, order=order)
#    1203
#    1204
#
# MemoryError: Unable to allocate 932. MiB for an array with shape (61065, 2000) and data type float64

# %%
#using Naive Bayes model
classifier_np = MultinomialNB()
classifier_np.fit(x_train_vectorizer, y_train)
# Out:
# MultinomialNB()

# %%
#Naive Bayes
y_pred_np = classifier_np.predict(x_test_vectorizer)
cm = confusion_matrix(y_test, y_pred_np)
print(cm)
# Out:
# [[9361 2147]
#  [1055 7792]]

# %%
#Accuracy of the naive bayes prediction model.
np_score = accuracy_score(y_test, y_pred_np)

print('Naive Bayes Accuracy: ', str(np_score))
# Out:
# Naive Bayes Accuracy:  0.8426922132154262

# %% [markdown]
# ## Save classifier

# %%
import pickle
with open('models/hatespeech_classifier.pkl', 'wb') as f:
    pickle.dump(classifier_np, f)
    
with open('models/hatespeech_vectorizer.pkl', 'wb') as f:
    pickle.dump(count, f)

# %%
import pickle
with open('models/hatespeech_classifier.pkl', 'rb') as f:
    classifier_np = pickle.load(f)
    
with open('models/hatespeech_vectorizer.pkl', 'rb') as f:
    count = pickle.load(f)

# %% [markdown]
# ## Implement the classifier

# %%
def detect_hatespeech(text):
    text=[p.clean(text)]
    text_vectorizer=count.transform(text)
    test_tfidf = tfidf.transform(text_vectorizer)
    prediction=classifier_np.predict(test_tfidf)
    category="none"
    if prediction[0]==0:
        category="not hateful"
    else:
        category="hateful and offensive"
    return category

# %%
fin_data['Hatespeech Category']=fin_data['Data'].apply(lambda x:detect_hatespeech(x))
fin_data.head(5)
# Out:
#                                                 Data  \
# 0   @Kenyans: Uhuru associating himself with Rail...
# 1   @gabrieloguda: BREAKING: A group of Posh Luos...
# 2   @FrankMtetezi: In the 48 Laws of power ,Never...
# 3   @DavisKRuto: Raila Odinga's name does not fea...
# 4   @kiraguisaac_22: H.E Uhuru kenyatta could not...
#
#                                                 tags            Politicians  \
# 0  [(Uhuru, POLITICIAN), (Raila, POLITICIAN), (Ma...  [Martha, Ruto, Uhuru]
# 1  [(Uhuru, POLITICIAN), (Raila, POLITICIAN), (Od...   [Ruto, Uhuru, Raila]
# 2      [(Uhuru, POLITICIAN), (Kenyatta, POLITICIAN)]      [Kenyatta, Uhuru]
# 3  [(Raila, POLITICIAN), (Odinga, POLITICIAN), (D...     [Ruto, Raila, Day]
# 4                              [(Uhuru, POLITICIAN)]                [Uhuru]
#
#    Vader_Sentiment Vader_Analysis    Hatespeech Category
# 0          -0.3182       Negative  hateful and offensive
# 1           0.2023       Positive  hateful and offensive
# 2           0.0000        Neutral  hateful and offensive
# 3           0.0000        Neutral            not hateful
# 4           0.0000        Neutral  hateful and offensive

# %%
def Hate_speech_and_offensive_language_analysis():
    h=len(fin_data.loc[(fin_data['Hatespeech Category']=="hateful and offensive")])
    nh=len(fin_data.loc[(fin_data['Hatespeech Category']=="not hateful")])
    y = np.array([h,nh])
    mylabels = ["Hateful and Offensive","Not Hateful"]
    myexplode = [0.05, 0]
    Colors=["red","green"]   

    fig, ax = plt.subplots(figsize = (10,6))
    ax.grid(False)
    plt.style.use('ggplot')

    plt.pie(y, labels = mylabels, explode = myexplode,colors=Colors, shadow = True, autopct='%1.0f%%')
    plt.legend()
    fig.set_facecolor('white')
    plt.title("Hatespeech and Offesive language Analysis")
    plt.show()

# %%
Hate_speech_and_offensive_language_analysis()
